# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd "/content/gdrive/MyDrive/Classroom/BME-Lab-513-Training/Ses-2"
# Out:
# /content/gdrive/MyDrive/Classroom/BME-Lab-513-Training/Ses-2

# %%
import numpy as np
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json('../acctress.json')
df.head()
# Out:
#    id          name japanName  ... blood_type     hobby  prefectures
# 0   3  Kitagawa Yui      北川ゆい  ...         AB  クラシックバレエ         None
# 1   4         Akira     Akira  ...          A    水泳、ゴルフ          東京都
# 2   6        Cocolo    COCOLO  ...          B      パソコン          茨城県
# 3   8         Saiko     Saiko  ...          O    料理、大食い          東京都
# 4  11     Aida Momo     あいだもも  ...          A    エアロビクス          東京都
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Check Overall of data

# %%
print(f'Number of features (columns): {df.shape[1]}')
print(f'Number of samples (rows): {df.shape[0]}')
# Out:
# Number of features (columns): 12
# Number of samples (rows): 11186

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11186 non-null  int64
#  1   name         11186 non-null  object
#  2   japanName    11186 non-null  object
#  3   hiragana     11186 non-null  object
#  4   bust         6456 non-null   float64
#  5   waist        6436 non-null   float64
#  6   hip          6428 non-null   float64
#  7   height       5012 non-null   float64
#  8   birthday     4031 non-null   object
#  9   blood_type   3171 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  4471 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.0+ MB

# %% [markdown]
# Problems:
#
# 1.Quá nhiều dữ liệu bị null
# + remove (rows--> bỏ sample) (cols --> bỏ feature)
# + fill(*)

# %% [markdown]
# + feature engineering
#
# --> create new features
#
# Tạo thêm thuộc tính độ tuổi (age)

# %%
# convert birthday to datetime object
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html
df['birthday'] = pd.to_datetime(df['birthday'], yearfirst = True)

# %%
df['age'] = 2021 - pd.DatetimeIndex(df['birthday']).year

# %%
df.head()
# Out:
#    id          name japanName hiragana  ...  blood_type     hobby  prefectures   age
# 0   3  Kitagawa Yui      北川ゆい   きたがわゆい  ...          AB  クラシックバレエ         None  41.0
# 1   4         Akira     Akira      あきら  ...           A    水泳、ゴルフ          東京都  43.0
# 2   6        Cocolo    COCOLO      こころ  ...           B      パソコン          茨城県  39.0
# 3   8         Saiko     Saiko      さいこ  ...           O    料理、大食い          東京都  38.0
# 4  11     Aida Momo     あいだもも    あいだもも  ...           A    エアロビクス          東京都  51.0
#
# [5 rows x 13 columns]

# %%
df.describe()
# Out:
#                  id         bust  ...       height          age
# count  1.118600e+04  6456.000000  ...  5012.000000  4031.000000
# mean   4.852872e+05    87.094253  ...   158.713148    36.704788
# std    5.076289e+05     6.155405  ...     5.814022     7.262923
# min    3.000000e+00    51.000000  ...   134.000000    20.000000
# 25%    7.189000e+03    83.000000  ...   155.000000    32.000000
# 50%    2.678500e+04    86.000000  ...   158.000000    36.000000
# 75%    1.026770e+06    90.000000  ...   163.000000    41.000000
# max    1.063061e+06   153.000000  ...   182.000000    66.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# + Tìm xem Idol trẻ tuổi nhất

# %%
df[df['age'] == df['age'].min()]
# Out:
#            id          name japanName  ... hobby  prefectures   age
# 9826  1059504    Maki Izuna      槙いずな  ...    読書          東京都  20.0
# 9933  1061822  Takeda Erena     武田エレナ  ...  None          静岡県  20.0
#
# [2 rows x 13 columns]

# %% [markdown]
# + Takeda Erena

# %% [markdown]
# +
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# + tìm idol có vòng 1 to nhất

# %%
df[df['bust'] == df['bust'].min()]
# Out:
#            id            name japanName  ... hobby  prefectures  age
# 8225  1037623  Minagawa Erena     皆川エレナ  ...  None         None  NaN
#
# [1 rows x 13 columns]

# %% [markdown]
# + ai thích thì search google thử đi nghen :> nhớ để tag ẩn danh.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11186 non-null  int64
#  1   name         11186 non-null  object
#  2   japanName    11186 non-null  object
#  3   hiragana     11186 non-null  object
#  4   bust         6456 non-null   float64
#  5   waist        6436 non-null   float64
#  6   hip          6428 non-null   float64
#  7   height       5012 non-null   float64
#  8   birthday     4031 non-null   datetime64[ns]
#  9   blood_type   3171 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  4471 non-null   object
#  12  age          4031 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
plt.figure(figsize = (10,5))
plt.hist(df['age'], bins = 200)
plt.show()

# %%
df['age'].values
# Out:
# array([41., 43., 39., ..., nan, nan, 37.])

# %%
plt.figure(figsize = (10, 5))
sns.boxplot(x = df['age'])
plt.show()

# %% [markdown]
# + nhìn nhanh ta thấy ngoài 55 tuổi có thể là outlier
#
# Nhưng để tìm chính xác hơn ta sử dụng công thức
# Interquartile Range (IQR)

# %%
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1

# %%
min_value = Q1 - 1.5 * IQR
max_value = Q3 + 1.5 * IQR

print(f'min_value = {min_value}')
print(f'max_value = {max_value}')
# Out:
# min_value = 18.5
# max_value = 54.5

# %%
min_outlier = (df['age'] < min_value).astype(int).sum()
max_outlier = (df['age'] > max_value).astype(int).sum()

print(f'min_outlier = {min_outlier}')
print(f'max_outlier = {max_outlier}')
# Out:
# min_outlier = 0
# max_outlier = 56

# %% [markdown]
# có 0 người dưới 18 tuổi và có 56 người từ 55 tuổi trở lên (thật là yêu nghề :> )

# %%
median_age = df['age'].median()
print(f'median_age = {median_age}')
# Out:
# median_age = 36.0

# %% [markdown]
# + if we fill nan in age equal to meadian age (36)

# %%
df['age'] = df['age'].fillna(median_age)

# %%
plt.figure(figsize = (10,5))
plt.hist(df['age'], bins = 200)
plt.show()

# %% [markdown]
# + thấy không ổn dòi

# %% [markdown]
# + điền các giá trị nan với kiểu phân phối chuẩn
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# %%
# reset value 
df['age'] = 2021 - pd.DatetimeIndex(df['birthday']).year

# %%
# remove outlier to calculate mean an std
mean = int(df[df['age'] < max_outlier]['age'].mean())
std = int(df[df['age'] < max_outlier]['age'].std())

print(f'mean = {mean}')
print(f'std = {std}')
# Out:
# mean = 36
# std = 6

# %%
gaussian = np.random.normal(loc = mean, scale = std, size = (len(index))).astype(int)

# %%
plt.figure(figsize = (10,5))
plt.hist(gaussian, bins = 200)
plt.show()

# %%
for i in range(len(index)):
  df['age'][index[i]] = gaussian[i]

# %%
df['age'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize = (10,5))
plt.hist(df['age'], bins = 200)
plt.show()

# %% [markdown]
# ### Tìm Idol theo tên

# %%
df[df['name'].str.contains('Maria')]
# Out:
#             id            name  ... prefectures   age
# 300      11714    Hayasi Maria  ...         東京都  37.0
# 382      11987      Maria Sara  ...        None  44.0
# 602      12889      Asai Maria  ...        None  44.0
# 697      13736    Hiziri Maria  ...         北海道  36.0
# 776      13994     Ogura Maria  ...        None  37.0
# 835      14485    Aoyama Maria  ...         千葉県  36.0
# 935      14864    Tamaki Maria  ...        None  51.0
# 968      15187     Ozawa Maria  ...         北海道  35.0
# 1473      1821  Nisimura Maria  ...        None  32.0
# 1658      1918    Sendou Maria  ...        None  48.0
# 1885     20651     Seino Maria  ...         東京都  33.0
# 2462     23224  Tominaga Maria  ...        None  39.0
# 2536     23568    Maria Dhizon  ...         東京都  34.0
# 2552      2286   Asakura Maria  ...         新潟県  43.0
# 2694     24253    Iizima Maria  ...              31.0
# 2706     24303  Himesaki Maria  ...         東京都  36.0
# 2771      2414    Watase Maria  ...        None  43.0
# 2993      2580    Hyuuga Maria  ...        None  34.0
# 3140      2584    Hidaka Maria  ...        None  25.0
# 3319     27817  Yamazaki Maria  ...              33.0
# 3789      2919    Yumeno Maria  ...         東京都  43.0
# 3817      2983    Yabuki Maria  ...        None  35.0
# 3993      3064  Tatibana Maria  ...        None  28.0
# 4070   1003393     Amane Maria  ...              28.0
# 4328   1005882    Kanata Maria  ...              33.0
# 4435   1006960   Maria Eriyori  ...         東京都  31.0
# 4780   1010392       Aoi Maria  ...              41.0
# 4837   1011020       Ono Maria  ...              35.0
# 4872   1011453  Nakamura Maria  ...              44.0
# 5013   1012514    Hanano Maria  ...              38.0
# 5153      3653   Kinouti Maria  ...        None  44.0
# 5903   1021099  Motiduki Maria  ...        None  31.0
# 6910   1027944  Wakatuki Maria  ...        None  28.0
# 7240   1030307    Sasaki Maria  ...        None  42.0
# 7268      4478  Sakagiti Maria  ...         東京都  38.0
# 7719   1033342           Maria  ...        None  48.0
# 8083   1036201    Haruno Maria  ...        None  44.0
# 8240   1037700      Aine Maria  ...        神奈川県  25.0
# 8476   1039866    Aizawa Maria  ...         埼玉県  27.0
# 8790   1043461  Hamasaki Maria  ...        None  36.0
# 8950   1045185  Morisaki Maria  ...        None  29.0
# 9140   1048280           Maria  ...        None  43.0
# 9392   1052247     Nagai Maria  ...        None  29.0
# 9570   1053612     Wakui Maria  ...         東京都  21.0
# 10076     5784     Hirai Maria  ...         兵庫県  38.0
# 10093     5843    Takagi Maria  ...         千葉県  43.0
# 10416     7081     Ozaki Maria  ...        None  46.0
# 10465      751     Yuuki Maria  ...        None  52.0
# 10622     7897       Abe Maria  ...        None  38.0
# 10963     9293     Maria Yuria  ...        None  38.0
# 10967      936  Kurosawa Maria  ...              44.0
#
# [51 rows x 13 columns]

# %% [markdown]
# ### Nghiên cứu sở thích của các idol

# %%
from wordcloud import WordCloud, ImageColorGenerator

# %%
hobby = df[df['hobby'].notnull()]

# %%
hobby.head()
# Out:
#    id          name japanName hiragana  ...  blood_type     hobby  prefectures   age
# 0   3  Kitagawa Yui      北川ゆい   きたがわゆい  ...          AB  クラシックバレエ         None  41.0
# 1   4         Akira     Akira      あきら  ...           A    水泳、ゴルフ          東京都  43.0
# 2   6        Cocolo    COCOLO      こころ  ...           B      パソコン          茨城県  39.0
# 3   8         Saiko     Saiko      さいこ  ...           O    料理、大食い          東京都  38.0
# 4  11     Aida Momo     あいだもも    あいだもも  ...           A    エアロビクス          東京都  51.0
#
# [5 rows x 13 columns]

# %%
# đưa tất cả các hobby về cùng 1 string 
hobby_str = "".join(hobby['hobby'])

# %%
hobby_str
# Out:
スケットピアノ、卓球、油絵英会話ダイビング、ピアノ旅行、テニスDVD鑑賞スポーツ全般アートネイル、犬と遊ぶこと、一輪車、料理カラオケ、おしゃべり読書ショッピングショッピング、カラオケカラオケ映画、音楽鑑賞ショッピングパソコン、エレクトーン、百人一首ダンスアイモード、メールの早打ちアロマテラピー絵画・エッセイ・イラスト・DJ料理、ショッピング読書バスケット、卓球スノーボード、剣道初段ネイルアート、ゴルフ、スキューバ、読書水泳、書道、カラーコーディネイト旅行、読書睡眠、読書マラソン、スキーテニス、ダンス音楽鑑賞、マッサージドライブクラブ、カラオケ、テニスショッピング、映画鑑賞、カラオケ、テニス料理、映画鑑賞ギターショッピング耳かき・ショッピング・ゲームピアノ・バレーボール/買い物ショッピング料理歌を歌うこと、絵を描くこと読書、写真、イラストスポーツ、カラオケ、ガチャピン関連グッズ収集、バスケットボール、フットサルネイルアート、バレーボール香水集め、英会話、ピアノ寝る事、マッサージ料理、バレーボールインターネットお菓子作り、カラオケ買い物、散歩、料理、新体操買い物、カラオケ絵画ピアノ、ダンス料理海、スノボ、ダンス、旅行、SEX買い物、ピアノ、クラリネットスノボー、トランペットネイルアート、料理散歩、ドラム映画鑑賞猫と遊ぶこと音楽鑑賞読書、掃除写真、作詞、歌外を見ること、カラオケ映画鑑賞料理、裁縫音楽鑑賞ボディーボードドライブ、ボーリング、ウォーキングトイストーリーグッズ集め、人間ウォッチングショッピングカラオケ水泳ショッピング料理料理、ピアノ、ボウリングネイルアート、歌映画鑑賞料理を作ること、テニス、スノーボード料理歌うことショッピングアウトドア、音楽鑑賞、スノーボードショッピングカラオケ、ショッピングネイルアート、映画鑑賞、料理ドライブ、海に行くことカラオケ、ヘアメイク、ダーツ書道、テニス、ショッピング映画鑑賞手芸、料理筋トレ、陸上、ピアノ居酒屋めぐり、犬の散歩、水泳、習字フィットネス、ピアノプリクラ、剣道読書、カラオケカラオケ、ショッピング、ダンス、料理体を動かすこと、ゴロゴロすることカラオケ、ポルトガル語料理、運動ショッピング、料理歌、ピアノ、マッサージ球体関節人形作り、音楽、映画鑑賞、パソコン、華道、フランス語旅行、料理、琴日本舞踊、茶道スノーボード、サーフィン読書、海水浴、キックボクシング音楽鑑賞、書道三段ショッピング、カラオケ、身体が柔らかいウィンドウショッピングショッピング、マッサージスポーツ、フットサル、バ ...

# %%
wordcloud  =WordCloud(font_path = 'jp.otf', max_words = 100, max_font_size = 30)

# %%
hobby_wc = wordcloud.generate(hobby_str)

# %%
plt.figure(figsize = (10, 10))
plt.imshow(hobby_wc)
plt.show()

# %%
# !ls
# Out:
#  acctress.json	 jp.otf
#  Jisoo.png	'Tìm hiểu văn hóa nước Nhật (Dự án về giáo dục).ipynb'

# %%
import cv2
from PIL import Image

# %%
mask_color = np.array(Image.open('../mask.png'))
mask_black = np.array(Image.open('../mask_black.png'))

# %%
wordcloud  = WordCloud(font_path = '../jp.otf', max_words = 100, max_font_size = 30, mask = mask_black, background_color = 'black')

# %%
hobby_wc = wordcloud.generate(hobby_str)

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
fig, axes = plt.subplots(1, 3)
axes[0].imshow(mask_color)
axes[1].imshow(mask_black)
axes[2].imshow(hobby_wc)
for ax in axes:
    ax.set_axis_off()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.imshow(hobby_wc)
plt.axis('off')
plt.show()
